# %% [markdown]
# # Data cleaning before training
#
# Data quality summary:
#
# 1000-level total reviews: 2189
#
# 2000-level total reviews: 871
#
# 3000-level total reviews: 424
#
# 4000-level total reviews: 316
#
# 5000-level total reviews: 104
#
#
# 1000-level course with comment count: 14
#
# 2000-level course with comment count: 8
#
# 3000-level course with comment count: 13
#
# 4000-level course with comment count: 37
#
# 5000-level course with comment count: 6
#
# Path：\IEDA3560_Project\ust_reviews\{course_name}\{course_name}_reviews.csv
#
# feature number= column number: 30
#
# feature names: ['hash', 'semester', 'instructors', 'is_author', 'author', 'date', 'title', 'comment_content', 'comment_teaching', 'comment_grading', 'comment_workload', 'rating_content', 'rating_teaching', 'rating_grading', 'rating_workload', 'has_midterm', 'has_final', 'has_quiz', 'has_assignment', 'has_essay', 'has_project', 'has_attendance', 'has_reading', 'has_presentation', 'upvote_count', 'vote_count', 'voted', 'is_upvote', 'comment_count', 'attachments']
#
#
# quality:
# A lot of binary variable, with integer, the comments are the mixture of Eng and Chin, with oral expression
# Some unique key can be dropped

# %% [markdown]
# Training:
#
# We will use random forest regression or classification as the baseline
#
# Second iteration: add more feature to evaluate the performance
#
#
# # Baseline Data Cleaning Rules:
#
# For each course csv file: in path \IEDA3560_Project\ust_reviews
# 1. Add the course_name as the tag for each csv fill the column with the column name on its path
# 2. Add the column: level,  for the fifth digit of the column course name if digit 5 =1 ==> fill:1000  ==2 ==> fill 2000 eg COMP1021 ==> fill 1000
# 3. Add a column: upvote_ratio, value for each cell  = upvote_count/ vote_count
# 4. Add a column: insturctor_name, value = get the first json in column instructors, key = name  which is the course insturtor name, we will use it to map professor rating from the raw data from
# https://ust-rankings.com/ ,
#
# the cleaned data path \IEDA3560_Project\ust_reviews\instructor_ranking.csv
#
# if the value in column insturctors = [], drop this row. recored the number of review dropped due to the empty insturctors value
#
# and we create a new column insturctor_rating to store the value after mapping the instructor name and its rating
#
# =  A+ =11 A=10 A-=9 B+=8, B=7, B-=6, C+=5, C=4, C-=3, D=2, E=1, F=0
#
# 5. sort the data with date, only keeping the data within recent 5 years e.g. date = xxx xx, year, year= range[2020,2026]
# 6. for each course keep at most 50 recent reviews
# 7. save a df_course_name with column  [ 'rating_workload', 'has_midterm', 'has_final', 'has_quiz', 'has_assignment', 'has_essay', 'has_project', 'has_attendance', 'has_reading', 'has_presentation','course_name,level,'upvote_ratio','insturctor_rating']
#
#  equipvalent to dropping ['hash', 'semester', 'instructors', 'is_author', 'author', 'date', 'title', 'comment_content', 'comment_teaching', 'comment_grading', 'comment_workload', 'rating_content', 'rating_teaching', 'rating_grading', 'upvote_count', 'vote_count', 'voted', 'is_upvote', 'comment_count', 'attachments', insturctor_name]
#
# 8. check the data remaining and iterate e.g. check how many value counted in total, if it filter out too much, then adjust the year range

# %%
from pathlib import Path
import ast
import numpy as np
import pandas as pd

# %%
# mapping function to define instructor score based on ranking
def build_instructor_score_map(ranking_path):
    rating_map = {
        "A+": 11, "A": 10, "A-": 9,
        "B+": 8, "B": 7, "B-": 6,
        "C+": 5, "C": 4, "C-": 3,
        "D": 2, "E": 1, "F": 0
    }

    rank_df = pd.read_csv(ranking_path, encoding="utf-8-sig")
    rank_df.columns = [c.strip() for c in rank_df.columns]

    if "instructor name" not in rank_df.columns or "ranking" not in rank_df.columns:
        raise ValueError("instructor_ranking.csv must contain: instructor name, ranking")

    rank_df["instructor name"] = rank_df["instructor name"].astype(str).str.strip()
    rank_df["ranking"] = rank_df["ranking"].astype(str).str.strip().str.upper()
    rank_df["insturctor_rating"] = rank_df["ranking"].map(rating_map)

    name_to_score = (
        rank_df.dropna(subset=["instructor name"])
               .drop_duplicates(subset=["instructor name"], keep="first")
               .set_index("instructor name")["insturctor_rating"]
               .to_dict()
    )
    return name_to_score, rank_df

RANKING_PATH = ROOT / "instructor_ranking.csv"
name_to_score, rank_df = build_instructor_score_map(RANKING_PATH)
display(rank_df.head())
# Out:
#   instructor name ranking     score  insturctor_rating
# 0  TSOI, Yau Chat      A+  0.675607                 11
# 1    FONG, Tsz Ho      A+  0.538155                 11
# 2      NG, Ka Man      A+  0.524646                 11
# 3    BAO, Zhigang      A+  0.508418                 11
# 4     ARYA, Sunil      A+  0.503023                 11

# %%
name_to_score
# Out:
# {'TSOI, Yau Chat': 11,
#  'FONG, Tsz Ho': 11,
#  'NG, Ka Man': 11,
#  'BAO, Zhigang': 11,
#  'ARYA, Sunil': 11,
#  'WONG, Raymond C W': 11,
#  'NASON, Stephen William': 11,
#  'WONG, James K.': 11,
#  'SHEN, Yiwen': 11,
#  'WONG, Tsz Wai': 11,
#  'WANG, Xuan': 11,
#  'JEONG, Martha': 11,
#  'LEUNG, Chi Man': 11,
#  'LIEM Rhea P': 11,
#  'LAW, Kam Tuen': 11,
#  'AU, Pak Hung': 11,
#  'CHAN, Gary Shueng Han': 11,
#  'SHEONG, Frederick Fu Kit': 11,
#  'IP, Ivan Chi Ho': 11,
#  'TANG, Rui': 11,
#  'ROSSITER, David': 11,
#  'WONG, Simon Man Ho': 11,
#  'HUANG, Yong': 11,
#  'CHENG, Kam Hang': 11,
#  'SIU, Wai Sze Grace': 11,
#  'KAFSHDAR GOHARSHADY, Amir': 11,
#  'ENGLAND, Graham James Fisher': 11,
#  'MENG, Zili': 11,
#  'SIU, Kam Wing': 11,
#  'CHEUNG, Kwok Yip': 11,
#  'HUA, Xinyu': 11,
#  'SHIOMI, Koji': 11,
#  'KAILA, Ilari Julius': 11,
#  'SHIEH, Tony': 11,
#  'SHI, Ling': 11,
#  'FU, Li-tsui': 11,
#  'YU, Yan': 11,
#  'GROVES, Julian Mcallister': 11,
#  'ZHANG, Hongtao': 11,
#  'LEUNG, Shing Yu': 11,
#  'XIA, Dong': 11,
#  'GIETEL-BASTEN, Stuart Arthur': 11,
#  'TAN, Jing': 11,
#  'FENG, Junlong': 11,
#  'DALTON, Amy N': 11,
#  'FRANKLIN, Laurence Craig': 11,
#  'XIE, Zhiyao': 11,
#  'LI, Larry': 11,
#  'HIRATA, Masayuki': 11,
#  'WANG, Lan': 11,
#  'PARK, Eunyoung': 11,
#  'CAI, Yongshun': 11,
#  'MAK, Hugo Wai Leung': 11,
#  'DU, Daisy Yan': 11,
#  'MURCH, Ross': 11,
#  'YAN, Lianke': 11,
#  'HE, Junxian': 11,
#  'BISETTI, Emilio': 11,
#  'HENDRY, David James': 11,
#  'ZHANG, Nevin Lianwen': 11,
#  'CHEN, Zhanhui': 11,
#  'XIA, Lucy': 11,
#  'CHAN, Man Sun': 11,
#  'RAO, Milind Shankar': 11,
#  'PAPADIAS, Dimitrios': 11,
#  'WANG, Jin': 11,
#  'WANG, Gang': 11,
#  'PEREIRA, Kevin Charles': 11,
#  'YOBAS, Levent': 11,
#  'HUANG, Allen H': 11,
#  'TSANG, Ming Wai Emily': 11,
#  'SAENYASIRI, Ekkachai': 11,
#  'ZHANG, Wenwen': 11,
#  'LAM, Gibson': 11,
#  'LYU, Guodong': 11,
#  'PAPADOPOULOS, Dimitris': 11,
#  'CHOI, Jaeho': 11,
#  'LEE, Byoungchan': 11,
#  'CHASNOV, Jeffrey Robert': 11,
#  'YEUNG, Dit Yan': 11,
#  'XIANG, Changying': 11,
#  'MUKHERJEE, Abhiroop': 11,
#  'JAISINGH, Jeevan': 11,
#  'POON, Andrew Wing On': 11,
#  'CHATZOPOULOS, Dimitrios': 11,
#  'XU, Ying': 11,
#  'WONG, Man': 11,
#  'POSADAS, Baryon Tensor': 11,
#  'WU, Angela Ruohao': 11,
#  'OKAT, Deniz': 11,
#  'ZHU, Yongchang': 11,
#  'PAGE, Timothy Markham': 11,
#  'FREESTONE, Pip': 11,
#  'SIU, Nicolson': 11,
#  'WANG, Caroline Chia-ling': 11,
#  'JIANG, Qingyuan': 11,
#  'AMIN, Aftab': 11,
#  'JI, Yan': 11,
#  'LIN, Yimin': 11,
#  'SONG, Shenghui': 11,
#  'WONG, Ellick Kin Fai': 11,
#  'LHABITANT, Francois-Serge': 11,
#  'DIAS, Garvin Percy': 11,
#  'LAM, Ngok': 11,
#  'SENGUPTA, Jaideep': 11,
#  'LIANG, Xin': 11,
#  'CHEN, Tai-Yuan': 11,
#  'HAN, Miaozhe': 11,
#  'WANG, Emily': 11,
#  'YAO, Jing': 11,
#  'ZHANG, Xiaojun': 11,
#  'CHOI, Ricky Yiu Kee': 11,
#  'WU, Shengqing': 11,
#  'GOHARSHADY, Amir': 11,
#  'TIAN, Bing': 11,
#  'DERMAN, Joshua': 11,
#  'YANG, Can': 11,
#  'TYRALA, Michael': 11,
#  'CHEN, Eva E': 11,
#  'SALVACRUZ, Joseph': 11,
#  'DROSCHA, Isaac David': 11,
#  'VONG, Kenward': 11,
#  'SEMMELHACK, Julie': 11,
#  'ZHU, Guang': 11,
#  'ZHOU, Catherine': 11,
#  'LEUNG, Siu Fai': 11,
#  'CHENG, Siu Wing': 11,
#  'LAU, Ronald Siu Man': 11,
#  'PARREAUX, Lionel': 11,
#  'WONG, T.Y. William': 11,
#  'KIM, Hyuncheol Bryant': 11,
#  'PENG, Zhichao': 11,
#  'LAU, Tak Yee': 11,
#  'WANG, Susheng': 11,
#  'LIN, Yi-Min': 11,
#  'VAN DER LANS, Ralf J A': 11,
#  'LI, Qing': 11,
#  'ZHAO, Xiaofan': 11,
#  'GAO, Zhenyu': 11,
#  'CHAN, Dennis Ho Wai': 11,
#  'LUONG, Howard Cam': 11,
#  'HE, Wenkai': 11,
#  'JING, Bing-yi': 11,
#  'SIMPSON, James Edward Barbour': 11,
#  'IP, Chi Ho Ivan': 11,
#  'BITTERLY, Thomas Bradford': 11,
#  'GOLIN, Mordecai Jay': 11,
#  'LI, Alvin': 11,
#  'XU, Kun': 11,
#  'LEUNG, Pak Wo': 11,
#  'PEGLER, Dominic James': 11,
#  'ALTMAN, Michael Scott': 11,
#  'TAM, Kevin Kim-Pong': 11,
#  'CHEUNG, Man Sing': 11,
#  'LEE, James': 11,
#  'TANG, Chao': 11,
#  'ZHOU, Rongrong': 11,
#  'VAN DER LINDE, Herald': 11,
#  'POO, Mu-chou': 11,
#  'SANDER, Pedro Vieira': 11,
#  'FAN, Linying Sophie': 11,
#  'FAN, Zhiyong': 11,
#  'YU, Man': 11,
#  'QIN, Zhen Quentin': 11,
#  'NG, Eric': 11,
#  'TANG TANG, Raymundo Saijong': 11,
#  'DU, Krista Yingzi': 11,
#  'PAN, Ding': 11,
#  'PARK, Sang Kyu': 11,
#  'CHAN, Roy K L': 11,
#  'CHI, Amy Man Lai': 11,
#  'VUICHARD, Pascal Bernard': 11,
#  'XU, Juanyi': 11,
#  'DI, Shimin': 11,
#  'SHARIF, Naubahar': 11,
#  'MAK, Andrew T C': 11,
#  'SHIH, Stephen L': 11,
#  'HO, Quoc Phu': 11,
#  'YOUSAF, Syeda Noor-ul-ain': 11,
#  'YANG, Zhengbao': 11,
#  'YEGEN, Eyub': 11,
#  'HE, Alex Jingwei': 11,
#  'PETROV, Evgeny': 11,
#  'NELSON, Eric S': 11,
#  'NGUYEN, Tuan Anh': 11,
#  'LAM, Henry H N': 11,
#  'HALPERT, Jonathan Eugene': 11,
#  'PO, Adrian': 11,
#  'FREEMAN, Danyal Jonathan': 11,
#  'SHROFF, Raj': 11,
#  'JIM, Monica': 11,
#  'ZHENG, YUE': 11,
#  'PI, Lynn': 11,
#  'THONG, James Y. L.': 11,
#  'SHARIF, Nau Bahar': 11,
#  'LAU, Pui Sang': 11,
#  'CHEUNG, Steven': 11,
#  'FU, Flora Li Tsui': 11,
#  'KU, Shuk Mei Agnes': 11,
#  'YIK, Michelle': 11,
#  'HAGMANN, David': 11,
#  'LI, Po Lung': 11,
#  'BENSAOU, Brahim': 11,
#  'CHO, Ja Ee': 11,
#  'HO, Ho Ming Stan': 11,
#  'NG, Wing Chung Vincent': 11,
#  'ZHENG, Wenjuan': 11,
#  'SRIVASTAVA, Abhishek K': 11,
#  'WANG, Zhe': 11,
#  'PENG, Qian': 11,
#  'HOLZ, Carsten Andreas': 11,
#  'SHEN, Shaojie': 11,
#  'WANG, Wenbo': 11,
#  'ZHOU, Tong': 11,
#  'LIU, Tao': 11,
#  'LAFON-VINAIS, Veronique J A': 11,
#  'SHIN, Dongwook': 11,
#  'LAI, Pui Yee': 11,
#  'LIU, Zhen': 11,
#  'MENG, Xiaoxuan': 11,
#  'WEN, Zilong': 11,
#  'JUNG SUH, .': 11,
#  'ZHOU, Yolanda Siyang': 11,
#  'LEUNG, Shui Yee': 11,
#  'MAK, Ho Yi': 11,
#  'MUTTO, Frederick': 11,
#  'ONGARO, Giulio': 11,
#  'PO, Hoi Chun': 11,
#  'LIU, Jianmei': 11,
#  'LEE, Janice': 11,
#  'ZHANG, Jun': 11,
#  'KIM, Hwa Young': 11,
#  'POON, Randy Yat Choi': 11,
#  'POTTER, Lorena': 11,
#  'LAU, Stanley C K': 11,
#  'LOW, Donald': 11,
#  'DING, Fei': 11,
#  'YARIME, Masaru': 11,
#  'ZWEIG, David Stephen': 11,
#  'CHAN, Ki Cecia': 11,
#  'ZHANG, James': 11,
#  'SIU, Grace': 11,
#  'TSE, Veronica W P': 11,
#  'YUE, Po Lock': 11,
#  'CHENG, Jack Chin Pang': 11,
#  'HONG, Jean (Ji Yeon)': 11,
#  'HUANG, Jiaming': 11,
#  'DING, Cunsheng': 11,
#  'LIN, Betty Fwei-chien': 11,
#  'PAGE, Timothy M.': 11,
#  'HUANG, Pingbo': 11,
#  'CHOW, Cupid': 11,
#  'SIU, Yat Fan': 11,
#  'SHI, Xiaoming Bill': 11,
#  'GUO, Yusong': 11,
#  'DEKREY, Steven John': 11,
#  'WANG, Shiheng': 11,
#  'LI, Mark Chi Yeung': 11,
#  'PARK, Hyo Keun': 11,
#  'LAW, Wai Ling': 11,
#  'MA, Robin': 11,
#  'YANG, Yansong': 11,
#  'LAM, Cheuk Fung': 11,
#  'SAN, Yik Chuen': 11,
#  'LIU, Y.S. Marshal': 11,
#  'XU, Hong': 11,
#  'TAM, Kim-Pong': 11,
#  'QIU, Xuan': 11,
#  'MOUNT, David': 11,
#  'WANG, Yi': 11,
#  'HUNG, Jenny': 11,
#  'CHAN, Jimmy W M': 11,
#  'TANG, Alfred Koon Him': 11,
#  'YI, Ke': 11,
#  'CHEE, Pui Yee': 11,
#  'LAKERVELD, Richard': 11,
#  'KIM, Yongsuk': 11,
#  'MA, Xiaolu': 11,
#  'SUN, Jingtao': 11,
#  'LI, Li': 11,
#  'QI, Jin': 11,
#  'HAN, Tianyu': 11,
#  'CHEN, Yangyang': 11,
#  'CAMPBELL, Cameron Dougall': 11,
#  'LAI, Marvin': 11,
#  'ZHANG, Yihan': 11,
#  'YIP, Kam Ming': 11,
#  'XU, Jenny J.': 11,
#  'NG, Billy': 11,
#  'GAO, Furong': 11,
#  'HORNER, Andrew Brian': 11,
#  'ZHANG, Li Min': 11,
#  'LI, Yingying': 11,
#  'CHEN, Zhihong': 11,
#  'LO, Yi-chin': 11,
#  'Michelle YIK': 11,
#  'ZHANG, Xiaowei': 11,
#  'LEUNG, Christopher Kin Ying': 11,
#  'CHEUNG, Tom': 11,
#  'Frank L Y Lam': 11,
#  'YU, Jianfeng': 11,
#  'NG, Ka Wai Tommy': 11,
#  'FONG, Yuk Fai': 11,
#  'HUANG, SETH H': 11,
#  'CHEN, Ying Ju': 11,
#  'LIU, Kai': 11,
#  'YU, Jialin': 11,
#  'PEREZ PALOMAR, Daniel': 11,
#  'IP, Sony': 11,
#  'LEUNG, Benjamin C S': 11,
#  'CHANG, Henry C Y': 11,
#  'SO, Pui San': 11,
#  'WU, Yueping': 11,
#  'HUI, Kai Lung': 11,
#  'MAK Kelvin P': 11,
#  'LO, Irene Man Chi': 11,
#  'QIU, Ada Xuan': 11,
#  'WONG, Yung Hou': 11,
#  'WU, Kam Yin': 11,
#  'CHAN, Chun Man': 11,
#  'LI, Sen': 11,
#  'HONG, Se-Joon': 11,
#  'LAM, Yeung Ho': 11,
#  'YU, Samuel Chung Toi': 10,
#  'FUNG, Terrance': 10,
#  'TSANG, Perseus': 10,
#  'JIN, Huan': 10,
#  'LI, Siya': 10,
#  'WONG, Grace Hoi Yee': 10,
#  'SCHARFF, Rob': 10,
#  'SHROFF, Rajendra Ravindra': 10,
#  'LAI, David T W': 10,
#  'FUNG, Jimmy Chi Hung': 10,
#  'YAN, Yan': 10,
#  'LI, Xinlei': 10,
#  'YANG, Daniel G.': 10,
#  'LAW, Chun Yin': 10,
#  'ZHANG, Rui': 10,
#  'WANG, Jing': 10,
#  'KITNEY, Paul': 10,
#  'LI, Yao Amber': 10,
#  'NITZSCHNER, Maximilian A': 10,
#  'XU, Xiufen': 10,
#  'CHEUNG, Shing-Chi': 10,
#  'JACOBSEN, Arno': 10,
#  'CHAN, Anthony Siu Lung': 10,
#  'XU, Xiaoyu': 10,
#  'LIN, Zhenyang': 10,
#  'NG, Ying Piu': 10,
#  'MA, Jingjing': 10,
#  'SHEN, Yajing': 10,
#  'GURUMURTHI, Suri': 10,
#  'WANG, Xin': 10,
#  'LEUNG, Suk Wai Winnie': 10,
#  'GONG, Yaping': 10,
#  'ZENG, Xiuwei': 10,
#  'RAO, Anyi': 10,
#  'CHANG, David C': 10,
#  'LEE, William W L': 10,
#  'TANG, Cindy': 10,
#  'GUO, Xinzhou': 10,
#  'MILLER, Andrew Leitch': 10,
#  'KWOK, Anson': 10,
#  'LIN, Song': 10,
#  'JIAN, Sisi': 10,
#  'YEUNG, Wai Mun Lucia': 10,
#  'DANIELS, Christian': 10,
#  'PARK, Sangyoon': 10,
#  'ZHENG, Xinghua': 10,
#  'ISHIBASHI, Toyotaka': 10,
#  'YOU, Wei': 10,
#  'ZHANG, Han': 10,
#  'GURUMURTHI, Suryanarayanan': 10,
#  'SEK, Ivy': 10,
#  'CHANG, Mang Yee': 10,
#  'LANVERSIN, Julien': 10,
#  'PROOI, Dennis': 10,
#  'CHEN Kevin C W': 10,
#  'YAN, He': 10,
#  'PAN, Ling': 10,
#  'NASH, John Gerard Francis': 10,
#  'SU, Hui': 10,
#  'CHANG, Donald Choy': 10,
#  'MAN, Tsz Yin': 10,
#  'SHU, Tse Mei Annie': 10,
#  'CHEN, Bo': 10,
#  'CHAN, Kwan Kit Jason': 10,
#  'JONEJA, Ajay': 10,
#  'ABEYNAYAKE, H.I. Malinda M.': 10,
#  'ZHENG, Shaohui': 10,
#  'HUANG, Xuhui': 10,
#  'KWAN, Joseph K C': 10,
#  'WONG, Man Yu': 10,
#  'MAN, Scottie': 10,
#  'XIA, Jun': 10,
#  'QIU, Wenting': 10,
#  'LI, Tin Lok': 10,
#  'POUND, Haydn Geoffrey': 10,
#  'ZHANG, Hai': 10,
#  'ZHANG, Min': 10,
#  'LI, Mitch': 10,
#  'ZHOU, Yuanyuan': 10,
#  'CLARK, Theodore Henry King': 10,
#  'CHEN, Wilbur': 10,
#  'QI, Robert Zhong': 10,
#  'HONG, Jiewen': 10,
#  'YANG, Chao': 10,
#  'DONG, Hao': 10,
#  'WONG, Kai Sun Albert': 10,
#  'LI, Ying': 10,
#  'REDONNET, Stephane': 10,
#  'GU, Dasa': 10,
#  'WONG, Michael Kwok Yee': 10,
#  'HUI, Sin Wah Cynthia': 10,
#  'SHU, Annie': 10,
#  'CHOI, Darwin': 10,
#  'LI, Zhigang': 10,
#  'CHUNG, Albert C S': 10,
#  'ZHU, Pengyu': 10,
#  'HUANG, Shilin': 10,
#  'USHIO, Masayuki': 10,
#  'NG, Chi Yung': 10,
#  'LEJANO, Raul P.': 10,
#  'GUO, Yves Zhiyi': 10,
#  'LEUNG, Ho Ming': 10,
#  'WANG, Jiying': 10,
#  'YANG, Jiachuan': 10,
#  'MA, Steve': 10,
#  'LEUNG, Wa Hung': 10,
#  'WAN, On Yu': 10,
#  'ZHANG, Lok Cheung Lawrence': 10,
#  'LAU, Brian Yee Huan': 10,
#  'WANG, Yu-Hsing': 10,
#  'ROSENFELD, Ahron': 10,
#  'LIM, Woo Young': 10,
#  'HO, Vincent Simon': 10,
#  'HSU, Charles Youyang': 10,
#  'LEE, Rolian': 10,
#  'BHAMBHWANI, Siddharth Mohankumar': 10,
#  'ABEYNAYAKE, Hiddadura Isura Malinda Mendis': 10,
#  'XIE, Wentao': 10,
#  'NAM, Sai Lok': 10,
#  'LAI, Beatrice Pui-yee': 10,
#  'YUNG, Ivan H H': 10,
#  'TANG, Yimeng': 10,
#  'LO, George Chi Wai': 10,
#  'LORETAN, Mico': 10,
#  'SO, Ka Yan': 10,
#  'CHAN, Yan Long': 10,
#  'YANG, Yi': 10,
#  'KIM, Jaesik': 10,
#  'ZHANG, Jingdi': 10,
#  'LAM, Martha Pik Har TANG': 10,
#  'NASIRY, Javad': 10,
#  'TO, Ka Ki': 10,
#  'LAU, Brian Hui Wang': 10,
#  'XIAO, Huiru': 10,
#  'LI, Xiaomeng': 10,
#  'LI, Jiatao': 10,
#  'WONG Derek': 10,
#  'LIU, Junwei': 10,
#  'FUNG, Eddy': 10,
#  'WANG, Yiwen': 10,
#  'KU, Agnes Shuk Mei': 10,
#  'CHEUNG, Man Fung': 10,
#  'LIU, Stephen': 10,
#  'CHAN, Hong To': 10,
#  'LIU, Qian': 10,
#  'CHOY, Ting Pong': 10,
#  'QIAO, Xi': 10,
#  'WU, Shanle': 10,
#  'KWOK, Felix': 10,
#  'NUO, Min': 10,
#  'JIN, Shuang': 10,
#  'CHAN, Jessica': 10,
#  'CHEN, Kani': 10,
#  'ZHANG, Xuning': 10,
#  'GUO, Zhihong': 10,
#  'BU, Guojun': 10,
#  'ZHANG, Rachel Q.': 10,
#  'FOK, Pik Lin': 10,
#  'TONG, Keith Sai Tao': 10,
#  'SHANG, Chii': 10,
#  'CHAN, Mansun': 10,
#  'BHAMHWANI, Siddharth': 10,
#  'KETCHUM, David Pattison': 10,
#  'PAPADIAS, Dimitris': 10,
#  'CARMICHAEL, Sarah': 10,
#  'ZHANG, Fumin': 10,
#  'BAI, Lian': 10,
#  'SUNADA, Kohei': 10,
#  'LAU, Ngai Ting': 10,
#  'LEUNG, Anthony': 10,
#  'LAM, Leung Yuk Frank': 10,
#  'WENG, Lutao': 10,
#  'DENG, Shuoqing': 10,
#  'MCKAY, Matthew Robert': 10,
#  'MUPPALA, Kumaraswamy R Jogesh': 10,
#  'WANG, Wen': 10,
#  'AGASSE, Roger': 10,
#  'NOZAWA, Yoshio': 10,
#  'CHIU, Eddy': 10,
#  'LI, Sai-Ping': 10,
#  'LI, Kai': 10,
#  'TSAI, Kellee S': 10,
#  'LEE, Ping Chung Eric': 10,
#  'ZHOU, Lingzhi': 10,
#  'LUO, Zhengtang': 10,
#  'BALASUBRAMANIAN, Sujata': 10,
#  'TECHNICAL THEATER ARTS PROGRAM, .': 10,
#  'MOK, Yuen Chuen Phoebe': 10,
#  'SO, Alvin Yiu-cheong': 10,
#  'WANG, Xiaoping': 10,
#  'YUNG, Hoi Hei': 10,
#  'ZHANG, Xin': 10,
#  'LU, Lijian': 10,
#  'TU, Fengbin': 10,
#  'SHUN, Chi Ming': 10,
#  'LAU, Vincent Kin Nang': 10,
#  'CHEUNG, Siu Woo': 10,
#  'KAUL, Mayank': 10,
#  'LIN, Ying': 10,
#  'XIE, Danyang': 10,
#  'HUI, Chun Man': 10,
#  'CHEN, Kevin Jing': 10,
#  'CLIVE LEE, .': 10,
#  'CHAN, Sandy W C': 10,
#  'TSE, Chris': 10,
#  'NGAN, Chi Cheung': 10,
#  'AN, Alicia': 10,
#  'CHOU, Hongsong': 10,
#  'COOK, David Edward': 10,
#  'CALENDRIER, Antoine Jacques Claude': 10,
#  'TSOU, Ka Yin Benjamin': 10,
#  'ACHUTAVARRIER PRASAD, Vinod': 10,
#  'LAU, Arthur': 10,
#  'BEN LETAIEF, Khaled': 10,
#  'LAM, Charles': 10,
#  'LEUNG, Patrick': 10,
#  'MOK, Elisabeth': 10,
#  'YOO, Hyek': 10,
#  'HU, Inchi': 10,
#  'PAN, Yuxin': 10,
#  'YAO, Yuan': 10,
#  'CHAN, Hilton Kwok Hung': 10,
#  'CHEN, Fei': 10,
#  'LAM, Kwan Nam': 10,
#  'MCLAUGHLIN, Rosie': 10,
#  'ZHOU, Wenwen': 10,
#  'ZHELYAZKOV, Pavel Ivanov': 10,
#  'CHANG, Briana': 10,
#  'LAM, Y Philip': 10,
#  'GAO, Hanyu': 10,
#  'WONG, William': 10,
#  'FORSTER, Paul Whitfield': 10,
#  'XIE, Ting': 10,
#  'OUYANG, Xiaomin': 10,
#  'HA, Albert Yiu Cheung': 10,
#  'FUNG, Ronald': 10,
#  'WONG, Dan': 10,
#  'LIU, Shan': 10,
#  'YIN, Ran': 10,
#  'CAI, Ning': 10,
#  'NAGL, Stefan': 10,
#  'QU, Jianan': 10,
#  'ONG, Madeline': 10,
#  'BEDFORD, Charles Ellwood': 10,
#  'WANG, Jingyi': 10,
#  'VALENTE, Giorgio': 10,
#  'RAO, Deyu': 10,
#  'CHEUNG, Muller Y M': 10,
#  'LOBELLO, Chris': 10,
#  'CHEN, Szu Fan': 10,
#  'CHAN, Althea In Suet': 10,
#  'ZHANG, Wenyi': 10,
#  'JHAVERI, Aditi': 10,
#  'HE, Dean': 10,
#  'TSANG, Dan': 10,
#  'ZHAO, Jidong': 10,
#  'KURT KEILHACKER, .': 10,
#  'VONG, King Ho Kenward': 10,
#  'WANG, Ning': 10,
#  'SO, Billy K L': 10,
#  'KI, Wing Hung': 10,
#  'SO, Richard Hau Yue': 10,
#  'FOONG, Leonie': 10,
#  'MA, Ruiqing': 10,
#  'GUAN, Yani': 10,
#  'TSANG, Alfred Jones': 10,
#  'VENEGAS, Salvador Morales': 10,
#  'LOH, Christine': 10,
#  'HE, Jian': 10,
#  'YOUSAF, Noorulain': 10,
#  'YIP, Victor Chi Lok': 10,
#  'KONG, Siu Kai': 10,
#  'LUDOVICE, Nicolo': 10,
#  'HUNG Mingyi': 10,
#  'ZHOU, Peng': 10,
#  'YI, Fangxin Francine': 10,
#  'MOW, Wai Ho': 10,
#  'PONG, Kam Keung': 10,
#  'PAPYSHEV, Gleb': 10,
#  'FUNG, Chi Hung': 10,
#  'SHAW, May-yi': 10,
#  'CHEN, Shensheng': 10,
#  'KO, Richard J': 10,
#  'LIU, Yanghe': 10,
#  'WU, Longjun': 10,
#  'WONG, Tony': 10,
#  'MA, John Z': 10,
#  'HOU, Yue': 10,
#  'DORAN, Christopher': 10,
#  'CHUNG, Yee Sing': 10,
#  'MILES, Steven B.': 10,
#  'ZHOU, Titi': 10,
#  'CHAN, CHRIS WH': 10,
#  'JIA, Jiaya': 10,
#  'MA, Jianxiong': 10,
#  'HO, Kwok Ping': 10,
#  'VISARIA, Sujata': 10,
#  'MA, Alex': 10,
#  'YAN, Dickson Yuk Shing': 10,
#  'XU, Xian': 10,
#  'LAI-REEVE, Sara': 10,
#  'HE, Chao': 10,
#  'LEE, Ching Kwan': 10,
#  'WAN, Chi Cheong': 10,
#  'NG, Jay Barry': 10,
#  'YANG, Hai': 10,
#  'FU, Wai On': 10,
#  'WAYE, Miu Yee Mary': 10,
#  'MSc in Global Operations': 10,
#  'JIANG, Wei': 10,
#  'WONG, Gilbert': 10,
#  'KELLER, Franziska Barbara': 10,
#  'LI, Shuo-hui': 10,
#  'GRIFFITH, Stephen Miles': 10,
#  'CHENG, Vennes': 10,
#  'HU, Shiman': 10,
#  'HUO, Lucy': 10,
#  'HU, Suyang': 10,
#  'CHENG, Weitao': 10,
#  'CHENG, Wai Ching Margaret': 10,
#  'HU, Xiaotao': 10,
#  'HU, Yike': 10,
#  'CHENG, Ip': 10,
#  'HU, Shengmin': 9,
#  'CHEN, Rui': 9,
#  'HUANG, Kunlong': 9,
#  'CHEN, Yufan': 9,
#  'HUNG, Ka Yee': 9,
#  'HUNG, Kennedy': 9,
#  'HU, Piao': 9,
#  'HU, Jiawei': 9,
#  'CHENG, Zhang': 9,
#  'HU, Haochen': 9,
#  'CHERAGH ZADE, Milad': 9,
#  'HU, Bo': 9,
#  'HSU, Ya-cheng': 9,
#  'HSU, Ke-cheng': 9,
#  'CHENG, Lixue': 9,
#  'HU, Yueying': 9,
#  'CHEN, Yuxin': 9,
#  'HUANG, Cong': 9,
#  'CHEN, Zhaoyi': 9,
#  'CHEN, Zhe': 9,
#  'CHEN, Zhixuan': 9,
#  'CHEN, Zhizhi': 9,
#  'CHEN, Zihao': 9,
#  'HUNG, Ming Yi': 9,
#  'CHEN, Yilin': 9,
#  'HUO, Yipeng': 9,
#  'HUANG, Rui': 9,
#  'CHEN, Xuanming': 9,
#  'HUANG, Zhi': 9,
#  'HUANG, Zhenghong': 9,
#  'HUANG, Yuzhen': 9,
#  'HUANG, Yutong': 9,
#  'HUANG, Yumeng': 9,
#  'CHEN, Yanfei': 9,
#  'CHEN, Yifan': 9,
#  'CHEN, Xin': 9,
#  'HUANG, Xuhong': 9,
#  'HUANG, Wen': 9,
#  'CHEN, Yifu': 9,
#  'HUANG, Hongyu': 9,
#  'HUANG, Ruizhao': 9,
#  'HUANG, Qifeng': 9,
#  'CHEN, Songqiang': 9,
#  'CHEN, Xinyu': 9,
#  'HUI, Cynthia': 9,
#  'CHEN, Yumeng': 9,
#  'CHEN, Shih Ta Michael': 9,
#  'JACKSON, Mark': 9,
#  'IVARSSON, Anna Katarina': 9,
#  'ISMAIL, Khaled Ibrahim Mohamed': 9,
#  'IP, Paul': 9,
#  'CHEN, Shi': 9,
#  'INTAN, Adriel Abraham': 9,
#  'INAM ULHAQAZAD': 9,
#  'IJAZ, Hamdoon': 9,
#  'HUI, Grace Suk Han': 9,
#  'CHEN, Shuijin': 9,
#  'CHEN, Zijun': 9,
#  'CHANG, Guozhen': 9,
#  'HUANG, Chenran': 9,
#  'KIM, Won Joon': 9,
#  'CHAU, Yu Foon Darin': 9,
#  'CHAN, Suk Sun': 9,
#  'KIM, Jaehyeok': 9,
#  'KIM, Jinwoo': 9,
#  'KIM, Jounghoon': 9,
#  'KIM, Sungrae': 9,
#  'CHAN, Raymond': 9,
#  'HU, Yulong': 9,
#  'CHAN, Wing Hong': 9,
#  'CHAN, Nga Teng': 9,
#  'CHAN, Kit William': 9,
#  'CHAN, King Yiu Chris': 9,
#  'KONG, Hao': 9,
#  'KONG, Wenzhi': 9,
#  'KANG, Kaifei': 9,
#  'JI, Jinghan': 9,
#  'CHEN, Mian': 9,
#  'CHEN, Limei': 9,
#  'JIANG, Ziming': 9,
#  'JIANG, Zhenliang': 9,
#  'JIANG, Wenjun': 9,
#  'JIANG, Ruochen': 9,
#  'CHEN, Mark': 9,
#  'JIANG, Mengqi': 9,
#  'JIANG, Hao': 9,
#  'CHEN, Junle': 9,
#  'JIA, Zhenyang': 9,
#  'JIA, Shiyue': 9,
#  'JIA, Mingkai': 9,
#  'JIA, Jing': 9,
#  'JIA, Guangnan': 9,
#  'KOU, Huanjia': 9,
#  'CHAN, Ho Shu': 9,
#  'KREJCI, Pav': 9,
#  'KHAN, Asif': 9,
#  'HUANG, Bingxin': 9,
#  'HUANG, Alan Z': 9,
#  'HU, Ziqi': 9,
#  'CHENG, Franklin Tat Fan': 9,
#  'CHENG, George': 9,
#  'HU, Zhixin': 9,
#  'HU, Yunzhi': 9,
#  'JAESIRI, On-mongkol': 9,
#  'JAVAHERI, Seyed Amirhossein': 9,
#  'KUAI, Qi': 9,
#  'CHAN, Yiu Ming': 9,
#  'KHODABAKHSHI, Nahid': 9,
#  'KHEDR, Ahmed Gamal Abdelsamea': 9,
#  'KHANAL, Samir Kumar': 9,
#  'KELLER, Wolfgang': 9,
#  'KO, Richard James Wei Hsin': 9,
#  'CHAN, Yan Nok': 9,
#  'KE, Yanyu': 9,
#  'GU, Richard': 9,
#  'CHAN, Wing Tung': 9,
#  'CHANG, Joshua': 9,
#  'KASIMU, Aliyu': 9,
#  'KARAHANNA-RAI, Elena': 9,
#  'CHAU, Wai Yi': 9,
#  'KANG, Xindan': 9,
#  'KANG, Suji': 9,
#  'KANG, Song': 9,
#  'CHAN, Wing Yan': 9,
#  'KHURANA, Vinayak': 9,
#  'KANG, Meng Chow': 9,
#  'HUANG, Yao Tung': 9,
#  'WANG, Yuqi': 9,
#  'LU, Lingfei': 9,
#  'WEN, Hailin': 9,
#  'WU, Junhong': 9,
#  'WEI, Jinchen': 9,
#  'WEI, Ning': 9,
#  'WEI, Vanessa': 9,
#  'WEI, Wei': 9,
#  'WEI, Zhifei': 9,
#  'WEN, Xudong': 9,
#  'WONG, Jackson': 9,
#  'WONG, Adrienne': 9,
#  'WONG, Cheuk Yuen': 9,
#  'WONG, Chun Fai Jeffrey': 9,
#  'WONG, Eugene': 9,
#  'WONG, Hanson': 9,
#  'WONG, Hei Tung': 9,
#  'WU, Qifan': 9,
#  'WAYE, Mary Miu Yee': 9,
#  'WU, Sherry Chen': 9,
#  'XIE, Xinying': 9,
#  'XIE, Songjie': 9,
#  'XIE, Minshan': 9,
#  'XIE, Linghui': 9,
#  'XIE, Lifang': 9,
#  'XIE, Jize': 9,
#  'XIAO, Yini': 9,
#  'XIAO, Siqi': 9,
#  'XIAO, Shihao': 9,
#  'XIAO, Jing': 9,
#  'XIAO, Jiacheng': 9,
#  'XIAO, Chengyu': 9,
#  'XIAN, Jiantang': 9,
#  'XIA, Xuemeng': 9,
#  'WONG, Hok Kam': 8,
#  'WONG, Kok Thong': 8,
#  'TBA': 8,
#  'SHI, Ziyi': 8,
#  'SHEN, Xingxing': 8,
#  'SHEN, Xinwei': 8,
#  'SHEN, Xirong': 8,
#  'SHENG, Xiaokang': 8,
#  'SHI, Jiaxin': 8,
#  'SHI, Yuhua': 8,
#  'SHIUE, Carol Hua': 8,
#  'WONG, Kwok Yee Michael': 8,
#  'SHRESTHA, Sudip': 8,
#  'SHU, Ji': 8,
#  'SHUM, Ka Shun': 8,
#  'SINGH, Gurmukh': 8,
#  'SINGH, Shivendra': 8,
#  'SIRIWEERA, Withanage Buddhima Sharmane': 8,
#  'SHEN, Leixian': 8,
#  'SHEN, Ke': 8,
#  'SHEN, Eric': 8,
#  'SHARMA, Ekisha': 8,
#  'SHAO, YiFan': 8,
#  'WAN, Lijuan': 8,
#  'WANG, Chaoqi': 8,
#  'XIE, Zheng': 8,
#  'WU, Peter Ching-ting': 8,
#  'WU, Jiahui': 8,
#  'WU, Hongfan': 8,
#  'WU, Hongbang': 8,
#  'WOO, Yuk Ying Patricia': 8,
#  'WONG, Yu Lam': 8,
#  'WONG, Tomas': 8,
#  'WONG, Raymond Man Hong': 8,
#  'WONG, Kwong Hing': 8,
#  'XIA, Kun': 8,
#  'WU, Zihao': 8,
#  'WU, Zhengzheng Catherine': 8,
#  'WANG, Zhengqi': 8,
#  'WANG, Yunpeng': 8,
#  'JI, Tianyi': 8,
#  'WANG, Yuren': 8,
#  'WANG, Ze Dong': 8,
#  'WANG, Zetao': 8,
#  'WANG, Zhaoyin': 8,
#  'WANG, Ziqi': 8,
#  'WU, Zhaoji': 8,
#  'WANG, Xiaoying': 8,
#  'WANG, Zixu': 8,
#  'WANG, Xiaoyang': 8,
#  'WANG, Xiao': 8,
#  'WANG, Dingxiang': 8,
#  'WANG, Dong': 8,
#  'WANG, Yuhong': 8,
#  'WANG, Yue': 8,
#  'WANG, Yucheng': 8,
#  'WANG, Yizheng': 8,
#  'WANG, Yirui': 8,
#  'WANG, Yinhuai': 8,
#  'WANG, Yige': 8,
#  'WANG, Yifei': 8,
#  'WANG, Yidan': 8,
#  'WANG, Yibo': 8,
#  'WANG, Yaqi': 8,
#  'WANG, Yanyuan': 8,
#  'WANG, Yanjia': 8,
#  'WANG, Yanghao': 8,
#  'WANG, Xuezhen': 8,
#  'WANG, Xinyu': 8,
#  'WANG, Xingze': 8,
#  'WANG, Hanlin': 8,
#  'WANG, Hanpeng': 8,
#  'WANG, Haodong': 8,
#  'WANG, Siyu': 8,
#  'WU, Yurong': 8,
#  'WU, Yifan': 8,
#  'WU, Yangfan': 8,
#  'WU, Yang': 8,
#  'WU, Xiaolong': 8,
#  'WU, Weinan': 8,
#  'WU, Si': 8,
#  'WEI, Fengxing': 8,
#  'WANG, Ziyi': 8,
#  'WANG, Dan': 8,
#  'WANG, Xiaojie': 8,
#  'WANG, Xi': 8,
#  'WANG, Wentao': 8,
#  'WANG, Tianshi': 8,
#  'WANG, Shuchen': 8,
#  'WANG, Hualiang': 8,
#  'WANG, Shu': 8,
#  'WANG, Shiqi': 8,
#  'WANG, Rui': 8,
#  'WANG, Qinyi': 8,
#  'WANG, Qiaoqiao': 8,
#  'WANG, Ping': 8,
#  'WANG, Pan': 8,
#  'WANG, Minghao': 8,
#  'WANG, Mimi': 8,
#  'WANG, Kaichen': 8,
#  'WANG, Jun': 8,
#  'WANG, Jue': 8,
#  'WANG, Josh': 8,
#  'WANG, Huan': 8,
#  'JI, Xinrong': 8,
#  'CHEUNG, Chong Mo': 8,
#  'JIANG, Zixuan': 8,
#  'KUSHNAZAROV, Mansurbek': 8,
#  'BHATTACHARYA, Saheli': 8,
#  'LAM, Wing In': 8,
#  'BI, Ying': 8,
#  'LAM, Tsz Kwan': 8,
#  'BIAN, Yuqian': 8,
#  'LAM, Shing Chi': 8,
#  'DUAN, Yixiao': 8,
#  'LAM, Sau Yee': 8,
#  'CHEN, Shuhao': 8,
#  'KU, Quan': 8,
#  'HAGHIGHI, Arman': 8,
#  'HAMDAOUI, Najoua': 8,
#  'HAN, Chih Kang': 8,
#  'CHUI, Yin To': 8,
#  'BHATTA, Aastha': 8,
#  'LAM, Yu Hong': 8,
#  'BHARWANEY, Shaneli Sham': 8,
#  'CEN, Yiting': 8,
#  'BHADRA, Debjyoti': 8,
#  'BERNAL, Marie': 8,
#  'LAM, SW': 8,
#  'CHAN, Cecia Ki': 8,
#  'LAU, KY Kitty': 8,
#  'BEDFORD, Charles E.': 8,
#  'LAU, Kong Leong': 8,
#  'BATISTA ARAUJO DE SOUSA, Raul': 8,
#  'LAU, Tin Lam Vanessa': 8,
#  'BARRIOS, Marcela': 8,
#  'LAU, Wing Fung': 8,
#  'CAO, Hui': 8,
#  'BAO, Xiaomeng': 8,
#  'HAN, Dongyu': 8,
#  'CHUI, Tsz Tou': 8,
#  'CHU, Zhuang': 8,
#  'GU, Jialei': 8,
#  'HE, Anwei': 8,
#  'CHOW, Ulysses': 8,
#  'GUO, Hongxiao': 8,
#  'GUO, Yue': 8,
#  'GUO, Yike': 8,
#  'GUO, Xiaowen': 8,
#  'CHUNG, Eric': 8,
#  'SO, Hau Yue Richard': 8,
#  'CHUNG, Kai Lun Peter': 8,
#  'CHUNG, Otto': 8,
#  'GUAN, Jingmeng': 8,
#  'CHOW, Yu Hang': 8,
#  'GU, Sophie J Y': 8,
#  'CHUNG, Yan Hon Michael': 8,
#  'CONWAY, Austin Eugene': 8,
#  'CHU, Meng': 8,
#  'COSTA, Antonino': 8,
#  'GONG, Xueping': 8,
#  'CUI, Duo': 8,
#  'GUO, Zhen': 8,
#  'GUO, Ziqing': 8,
#  'CHUNG, Ching': 8,
#  'HA, Tan Sang': 8,
#  'CHOY, Henry': 8,
#  'HAO, Jingyu': 8,
#  'CHOY, Stephanie': 8,
#  'CHOY, Yee Lam': 8,
#  'HAN, Yingyue': 8,
#  'CHU, Ka Wing Stefan': 8,
#  'HAN, Xiaoyu': 8,
#  'BAO, Hongyu': 8,
#  'BOSE, Turzo': 8,
#  'HO, Kin Yan Kevin': 8,
#  'AROKIARAJ, Aloysius Wilfred Raj': 8,
#  'LEUNG, Bing Shin': 8,
#  'LEUNG, Sze Nga Jessica': 8,
#  'LEUNG, Benson': 8,
#  'LEUNG, Aki': 8,
#  'LEUNG, Tak Ming': 8,
#  'LEJANO, Raul Perez': 8,
#  'LEI, Zhibin': 8,
#  'LE, Minh Ngoc': 8,
#  'AU YEUNG, Kin Nam': 8,
#  'LEUNG, Tin Long': 8,
#  'ANZOLA JUERGENSON, Alex': 8,
#  'LEE, Siu Keung': 8,
#  'AN, Tailin': 8,
#  'LEE, Sapere KK': 8,
#  'LEUNG, Chun Yin': 8,
#  'ARGA, Hanz Kristien': 8,
#  ...}

# %%
# helper function to extract course instructor name from the raw instructor column, which can be a string or a list of dicts
def parse_first_instructor_name(x):
    if pd.isna(x):
        return np.nan

    try:
        value = x

        if isinstance(value, str):
            value = value.strip()
            if not value or value == "[]":
                return np.nan
            value = ast.literal_eval(value)

        if isinstance(value, list) and len(value) > 0:
            first_item = value[0]
            if isinstance(first_item, dict):
                name = first_item.get("name")
                if pd.notna(name) and str(name).strip():
                    return str(name).strip()
            elif isinstance(first_item, str):
                return first_item.strip() or np.nan

        return np.nan
    except Exception:
        return np.nan

# %%
# helper function to extract course level from course name 
def get_level(course_name):
    # COMP1021 -> 1000
    try:
        d = str(course_name)[4]
        if d.isdigit():
            return int(d) * 1000
    except Exception:
        pass
    return np.nan

# %%
# cleaning for a single course file, return cleaned df and stats
TARGET_COLS = [
    "rating_workload",
    "has_midterm", "has_final", "has_quiz", "has_assignment", "has_essay",
    "has_project", "has_attendance", "has_reading", "has_presentation",
    "course_name", "level", "upvote_ratio", "insturctor_rating"
]
def clean_one_course_file(
    fp,
    name_to_score,
    min_year=2020,
    max_year=2026,
    output_root=None,
    max_reviews_per_course=50
):
    course_name = fp.stem.replace("_reviews", "")
    df = pd.read_csv(fp, encoding="utf-8-sig")
    input_rows = len(df)

    df["course_name"] = course_name
    df["level"] = get_level(course_name)

    df["upvote_count"] = pd.to_numeric(df.get("upvote_count"), errors="coerce")
    df["vote_count"] = pd.to_numeric(df.get("vote_count"), errors="coerce")
    df["upvote_ratio"] = np.where(
        df["vote_count"].fillna(0) > 0,
        df["upvote_count"].fillna(0) / df["vote_count"],
        np.nan
    )

    df["insturctor_name"] = df.get(
        "instructors",
        pd.Series(index=df.index, dtype=object)
    ).apply(parse_first_instructor_name)

    before_drop_inst = len(df)
    df = df[df["insturctor_name"].notna()].copy()
    dropped_empty_instructors = before_drop_inst - len(df)

    df["insturctor_rating"] = df["insturctor_name"].map(name_to_score)

    df["date_parsed"] = pd.to_datetime(df.get("date"), errors="coerce")
    before_drop_year = len(df)
    df = df[df["date_parsed"].dt.year.between(min_year, max_year, inclusive="both")].copy()
    dropped_out_of_year_range = before_drop_year - len(df)

    # Keep at most N most recent reviews per course
    before_cap = len(df)
    df = df.sort_values("date_parsed", ascending=False).head(max_reviews_per_course).copy()
    dropped_by_cap = before_cap - len(df)

    for c in TARGET_COLS:
        if c not in df.columns:
            df[c] = np.nan
    df_out = df[TARGET_COLS].copy()

    if output_root is not None:
        course_out_dir = output_root / course_name
        course_out_dir.mkdir(parents=True, exist_ok=True)
        out_path = course_out_dir / f"{course_name}_cleaned.csv"
        df_out.to_csv(out_path, index=False, encoding="utf-8-sig")

    stats = {
        "course_name": course_name,
        "input_rows": input_rows,
        "dropped_empty_instructors": dropped_empty_instructors,
        "dropped_out_of_year_range": dropped_out_of_year_range,
        "dropped_by_cap": dropped_by_cap,
        "output_rows": len(df_out)
    }
    return df_out, stats

# %%
# test with comp1021 
MAX_REVIEWS_PER_COURSE = 50
max_reviews_per_course=MAX_REVIEWS_PER_COURSE

fp = ROOT / "COMP1021" / "COMP1021_reviews.csv"
out_dir = Path(r"C:\Users\aazh0\Desktop\IEDA3560_Project\ust_review_cleanned_baseline")
out_dir.mkdir(parents=True, exist_ok=True)

df_comp1021_cleaned, stats_comp1021 = clean_one_course_file(
    fp=fp,
    name_to_score=name_to_score,
    min_year=2020,
    max_year=2026,
    output_root=out_dir
)

df_comp1021_cleaned.head()
# Out:
#      rating_workload  has_midterm  has_final  has_quiz  has_assignment  \
# 115                5         True       True     False           False
# 116                4         True       True     False            True
# 27                 5         True       True     False            True
# 117                5         True       True     False            True
# 28                 2         True       True     False            True
#
#      has_essay  has_project  has_attendance  has_reading  has_presentation  \
# 115      False        False           False        False             False
# 116      False        False           False        False             False
# 27       False        False           False        False             False
# 117      False        False           False        False             False
# 28       False        False           False        False              True
#
#     course_name  level  upvote_ratio  insturctor_rating
# 115    COMP1021   1000           NaN               11.0
# 116    COMP1021   1000           NaN               11.0
# 27     COMP1021   1000           1.0                NaN
# 117    COMP1021   1000           NaN               11.0
# 28     COMP1021   1000           1.0                NaN

# %%
stats_comp1021
# Out:
# {'course_name': 'COMP1021',
#  'input_rows': 1234,
#  'dropped_empty_instructors': 190,
#  'dropped_out_of_year_range': 211,
#  'dropped_by_cap': 783,
#  'output_rows': 50}

# %%
def clean_all_courses(root=ROOT, name_to_score=None, min_year=MIN_YEAR, max_year=MAX_YEAR, output_root=OUTPUT_ROOT):
    files = sorted(root.glob("COMP*/COMP*_reviews.csv"))
    if not files:
        raise FileNotFoundError("No course review csv found under ./ust_reviews")
    if name_to_score is None:
        raise ValueError("name_to_score is required")

    all_cleaned = []
    report_rows = []

    for fp in files:
        df_out, stats = clean_one_course_file(
            fp=fp,
            name_to_score=name_to_score,
            min_year=min_year,
            max_year=max_year,
            output_root=output_root
        )
        all_cleaned.append(df_out)
        report_rows.append(stats)

    df_all_cleaned = pd.concat(all_cleaned, ignore_index=True)
    report_df = pd.DataFrame(report_rows).sort_values("output_rows", ascending=False)

    df_all_cleaned.to_csv(output_root / "all_courses_cleaned.csv", index=False, encoding="utf-8-sig")
    report_df.to_csv(output_root / "cleaning_report.csv", index=False, encoding="utf-8-sig")

    return df_all_cleaned, report_df

# %%
MAX_REVIEWS_PER_COURSE = 50
max_reviews_per_course=MAX_REVIEWS_PER_COURSE
ROOT = Path("./ust_reviews")  # input: raw data reviews
OUTPUT_ROOT = Path(r"C:\Users\aazh0\Desktop\IEDA3560_Project\ust_review_cleanned_baseline")  # output: 清洗後資料
RANKING_PATH = ROOT / "instructor_ranking.csv"

MIN_YEAR = 2020
MAX_YEAR = 2026

OUTPUT_ROOT.mkdir(parents=True, exist_ok=True)

# %%
df_all_cleaned, report_df = clean_all_courses(
    root=ROOT,
    name_to_score=name_to_score,
    min_year=MIN_YEAR,
    max_year=MAX_YEAR,
    output_root=OUTPUT_ROOT
)

total_input = report_df["input_rows"].sum()
total_drop_inst = report_df["dropped_empty_instructors"].sum()
total_drop_year = report_df["dropped_out_of_year_range"].sum()
total_output = report_df["output_rows"].sum()
total_drop_cap = report_df["dropped_by_cap"].sum()


print("==== Cleaning Summary ====")
print("Total input rows:", total_input)
print("Dropped due to empty instructors:", total_drop_inst)
print(f"Dropped due to year filter [{MIN_YEAR}, {MAX_YEAR}]:", total_drop_year)
print(f"Dropped due to per-course cap ({MAX_REVIEWS_PER_COURSE}):", total_drop_cap)
print("Total output rows:", total_output)
print("Retention ratio:", f"{(total_output / total_input):.2%}" if total_input > 0 else "N/A")

display(report_df.head(20))
display(df_all_cleaned.head(20))
# Out:
# ==== Cleaning Summary ====
# Total input rows: 3904
# Dropped due to empty instructors: 436
# Dropped due to year filter [2020, 2026]: 1123
# Dropped due to per-course cap (50): 1047
# Total output rows: 1298
# Retention ratio: 33.25%
#    course_name  input_rows  dropped_empty_instructors  \
# 14    COMP2011         311                         43
# 2    COMP1022P         356                         40
# 15    COMP2012         109                          8
# 4     COMP1023          63                          7
# 1     COMP1021        1234                        190
# 32    COMP3711          73                          7
# 17    COMP2211          60                          3
# 21   COMP2711H          66                          0
# 20    COMP2711         177                         19
# 16   COMP2012H          75                          2
# 28    COMP3511          67                          4
# 10    COMP1942          73                          3
# 22    COMP3021          51                          1
# 3    COMP1022Q         231                         14
# 0     COMP1001          74                         14
# 73    COMP5212          43                          7
# 18    COMP2611          62                          2
# 24    COMP3111          62                          4
# 12    COMP1944          31                          2
# 27    COMP3311          49                          4
#
#     dropped_out_of_year_range  dropped_by_cap  output_rows
# 14                         85             133           50
# 2                         224              42           50
# 15                         36              15           50
# 4                           0               6           50
# 1                         211             783           50
# 32                         14               2           50
# 17                          0               7           50
# 21                         13               3           50
# 20                         52              56           50
# 16                         25               0           48
# 28                         15               0           48
# 10                         26               0           44
# 22                         12               0           38
# 3                         179               0           38
# 0                          23               0           37
# 73                          0               0           36
# 18                         24               0           36
# 24                         26               0           32
# 12                          0               0           29
# 27                         18               0           27
#     rating_workload  has_midterm  has_final  has_quiz  has_assignment  \
# 0                 4        False       True      True           False
# 1                 3         True       True     False           False
# 2                 5        False       True      True           False
# 3                 5        False       True      True           False
# 4                 4        False       True      True            True
# 5                 4        False       True     False            True
# 6                 4        False       True      True           False
# 7                 5        False       True      True            True
# 8                 5        False       True     False            True
# 9                 4        False       True     False            True
# 10                4        False       True      True           False
# 11                3        False       True     False           False
# 12                4        False       True      True            True
# 13                4        False       True      True           False
# 14                4        False       True      True           False
# 15                5        False       True      True           False
# 16                4         True       True      True            True
# 17                4        False       True     False            True
# 18                5        False       True      True            True
# 19                4        False       True      True            True
#
#     has_essay  has_project  has_attendance  has_reading  has_presentation  \
# 0       False         True            True        False             False
# 1       False         True           False        False             False
# 2       False         True            True         True              True
# 3       False         True            True        False              True
# 4       False         True            True        False              True
# 5       False         True            True        False             False
# 6       False         True           False        False             False
# 7       False         True            True        False              True
# 8       False         True            True        False             False
# 9       False         True            True        False             False
# 10      False         True            True        False              True
# 11      False        False           False        False             False
# 12      False         True            True         True             False
# 13      False         True            True        False             False
# 14      False         True            True        False              True
# 15      False         True            True        False             False
# 16      False         True            True        False             False
# 17      False         True           False        False             False
# 18      False         True            True        False              True
# 19      False         True            True        False             False
#
#    course_name  level  upvote_ratio  insturctor_rating
# 0     COMP1001   1000           NaN                0.0
# 1     COMP1001   1000           NaN                0.0
# 2     COMP1001   1000           NaN                0.0
# 3     COMP1001   1000           NaN                0.0
# 4     COMP1001   1000           NaN                0.0
# 5     COMP1001   1000           NaN                0.0
# 6     COMP1001   1000           NaN                0.0
# 7     COMP1001   1000      0.500000                0.0
# 8     COMP1001   1000      0.500000                0.0
# 9     COMP1001   1000      0.000000                0.0
# 10    COMP1001   1000      0.666667                0.0
# 11    COMP1001   1000      0.000000                0.0
# 12    COMP1001   1000      1.000000                0.0
# 13    COMP1001   1000      1.000000                0.0
# 14    COMP1001   1000           NaN                0.0
# 15    COMP1001   1000      0.500000                0.0
# 16    COMP1001   1000      1.000000                0.0
# 17    COMP1001   1000      0.000000                0.0
# 18    COMP1001   1000           NaN                0.0
# 19    COMP1001   1000           NaN                0.0

# %%
report_df.head(20)
# Out:
#    course_name  input_rows  dropped_empty_instructors  \
# 14    COMP2011         311                         43
# 2    COMP1022P         356                         40
# 15    COMP2012         109                          8
# 4     COMP1023          63                          7
# 1     COMP1021        1234                        190
# 32    COMP3711          73                          7
# 17    COMP2211          60                          3
# 21   COMP2711H          66                          0
# 20    COMP2711         177                         19
# 16   COMP2012H          75                          2
# 28    COMP3511          67                          4
# 10    COMP1942          73                          3
# 22    COMP3021          51                          1
# 3    COMP1022Q         231                         14
# 0     COMP1001          74                         14
# 73    COMP5212          43                          7
# 18    COMP2611          62                          2
# 24    COMP3111          62                          4
# 12    COMP1944          31                          2
# 27    COMP3311          49                          4
#
#     dropped_out_of_year_range  dropped_by_cap  output_rows
# 14                         85             133           50
# 2                         224              42           50
# 15                         36              15           50
# 4                           0               6           50
# 1                         211             783           50
# 32                         14               2           50
# 17                          0               7           50
# 21                         13               3           50
# 20                         52              56           50
# 16                         25               0           48
# 28                         15               0           48
# 10                         26               0           44
# 22                         12               0           38
# 3                         179               0           38
# 0                          23               0           37
# 73                          0               0           36
# 18                         24               0           36
# 24                         26               0           32
# 12                          0               0           29
# 27                         18               0           27

# %%
df_all_cleaned.head()
# Out:
#    rating_workload  has_midterm  has_final  has_quiz  has_assignment  \
# 0                4        False       True      True           False
# 1                3         True       True     False           False
# 2                5        False       True      True           False
# 3                5        False       True      True           False
# 4                4        False       True      True            True
#
#    has_essay  has_project  has_attendance  has_reading  has_presentation  \
# 0      False         True            True        False             False
# 1      False         True           False        False             False
# 2      False         True            True         True              True
# 3      False         True            True        False              True
# 4      False         True            True        False              True
#
#   course_name  level  upvote_ratio  insturctor_rating
# 0    COMP1001   1000           NaN                0.0
# 1    COMP1001   1000           NaN                0.0
# 2    COMP1001   1000           NaN                0.0
# 3    COMP1001   1000           NaN                0.0
# 4    COMP1001   1000           NaN                0.0

# %%
total_rows = len(df_all_cleaned)
nan_upvote_ratio_count = df_all_cleaned["upvote_ratio"].isna().sum()

print("Total rows:", total_rows)
print("upvote_ratio is NaN:", nan_upvote_ratio_count)
# Out:
# Total rows: 1298
# upvote_ratio is NaN: 471

# %%
level1_df = df_all_cleaned[df_all_cleaned["level"] == 1000].copy()
print("Level 1000 rows:", len(level1_df))
level2_df = df_all_cleaned[df_all_cleaned["level"] == 2000].copy()
print("Level 2000 rows:", len(level2_df))
level3_df = df_all_cleaned[df_all_cleaned["level"] == 3000].copy()
print("Level 3000 rows:", len(level3_df))
level4_df = df_all_cleaned[df_all_cleaned["level"] == 4000].copy()
print("Level 4000 rows:", len(level4_df))
level5_df = df_all_cleaned[df_all_cleaned["level"] == 5000].copy()
level5_df.head()
print("Level 5000 rows:", len(level5_df))
# Out:
# Level 1000 rows: 368
# Level 2000 rows: 342
# Level 3000 rows: 285
# Level 4000 rows: 221
# Level 5000 rows: 82

# %%
# check review distribution over the course level 
level_course_counts = (
    df_all_cleaned
    .groupby(["level", "course_name"], as_index=False)
    .size()
    .rename(columns={"size": "review_count"})
    .sort_values(["level", "review_count"], ascending=[True, False])
)

level_course_counts[level_course_counts["level"] == 1000]
# Out:
#     level course_name  review_count
# 1    1000    COMP1021            50
# 2    1000   COMP1022P            50
# 4    1000    COMP1023            50
# 10   1000    COMP1942            44
# 3    1000   COMP1022Q            38
# 0    1000    COMP1001            37
# 12   1000    COMP1944            29
# 6    1000   COMP1029C            17
# 7    1000   COMP1029J            15
# 9    1000   COMP1029V            15
# 11   1000    COMP1943            14
# 8    1000   COMP1029P             7
# 5    1000    COMP1028             2

# %%
level_course_counts[level_course_counts["level"] == 2000]
# Out:
#     level course_name  review_count
# 13   2000    COMP2011            50
# 14   2000    COMP2012            50
# 16   2000    COMP2211            50
# 19   2000    COMP2711            50
# 20   2000   COMP2711H            50
# 15   2000   COMP2012H            48
# 17   2000    COMP2611            36
# 18   2000    COMP2633             8

# %%
level_course_counts[level_course_counts["level"] == 3000]
# Out:
#     level course_name  review_count
# 31   3000    COMP3711            52
# 27   3000    COMP3511            48
# 21   3000    COMP3021            38
# 23   3000    COMP3111            32
# 26   3000    COMP3311            27
# 22   3000    COMP3031            24
# 33   3000    COMP3721            18
# 25   3000    COMP3211            14
# 32   3000   COMP3711H            14
# 29   3000    COMP3632             8
# 24   3000   COMP3111H             6
# 28   3000    COMP3631             4
# 30   3000    COMP3633             2

# %%
level_course_counts[level_course_counts["level"] == 4000]
# Out:
#     level course_name  review_count
# 36   4000    COMP4211            22
# 45   4000    COMP4441            17
# 34   4000    COMP4021            13
# 43   4000    COMP4421            12
# 44   4000    COMP4431            11
# 41   4000    COMP4332             9
# 49   4000    COMP4471             9
# 61   4000    COMP4651             9
# 42   4000    COMP4411             8
# 50   4000    COMP4521             8
# 56   4000    COMP4632             8
# 37   4000    COMP4221             7
# 40   4000    COMP4331             7
# 65   4000   COMP4901U             7
# 39   4000    COMP4321             6
# 54   4000    COMP4621             6
# 38   4000    COMP4222             5
# 47   4000    COMP4461             5
# 48   4000    COMP4462             5
# 63   4000   COMP4901N             5
# 66   4000   COMP4901W             5
# 67   4000   COMP4901Y             5
# 52   4000    COMP4541             4
# 53   4000    COMP4611             4
# 60   4000    COMP4641             4
# 46   4000    COMP4451             3
# 55   4000    COMP4631             3
# 58   4000    COMP4634             3
# 35   4000    COMP4121             2
# 51   4000    COMP4531             2
# 57   4000    COMP4633             2
# 64   4000   COMP4901O             2
# 59   4000    COMP4635             1
# 62   4000   COMP4901K             1
# 68   4000    COMP4981             1

# %%
level_course_counts[level_course_counts["level"] == 5000]
# Out:
#     level course_name  review_count
# 70   5000    COMP5212            36
# 73   5000    COMP5621            22
# 69   5000    COMP5211            13
# 74   5000    COMP5631             6
# 72   5000    COMP5311             4
# 71   5000    COMP5221             1
